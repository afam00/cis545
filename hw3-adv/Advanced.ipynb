# %% [markdown]
# # Step 5. Advanced: tf-idf search engine
# Now that you have implemented PageRank, which tells you how authoritative websites are, you are going to build the other very important part of a search engine. Namely, this part will retrieve the documents that are _relevant_ to a given query. Simply put, this part will give you a subset of webpages that are presumed to be relevant to the query and then PageRank can rerank them according to how much you value authoritativeness over relevance. The methods in this section are a basis of both _keyword search_, and also _document clustering_.  (We’ll see a lot more about clustering in a few weeks.)

# %% [markdown]
# ## Step 5.1. Preliminaries
#
# ### Step 5.1.1. Load nltk and some helpful tools
#
# The cell below gives you some tools and assigns some variables that you will need later. You do not need to modify this cell provided that you have everything installed already.

# %%
# Uncomment the next line if you have not installed nltk already
#! pip install nltk
import nltk

# Uncomment the next line if you would like to have nltk_data accessible on your computer
nltk.data.path = ['/home/jovyan/work/nltk_data']
# Remember to check whether the config was successfully changed if you do it this way

# Uncomment the next line if you still need to download punkt
# nltk.download()
# Enter 'd' for Download, then 'punkt', and then 'q' for quit

from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

import numpy as np
import re

"""
# Returns True if the input (string) parameter has
# any sort of letter in it, else returns False.
"""
def has_letter(x):
    return re.match('.*[a-zA-Z].*',x) != None

# Stopwords are words we will ignore for search
# purposes, because they are too common to be useful
stopwords = set()

stop_file = open('stopwords.txt')
for line in stop_file:
    stopwords.add(line.strip())

# The NLTK parser breaks apostrophe-s into a separate "word"
# so we'll want to add it to the list... Though it's technically
# not a stop word in the traditional sense.
stopwords.add("'s")

# Use this as the maximum number of words we will index
MAX_WORDS = 10000

# Create the word stemmer
stemmer = PorterStemmer()

# %% [markdown]
# ### Step 5.1.2. Import text files, clean them, and store in a dictionary
#
# As a "corpus" we fetched some data from Wikipedia, based on currently
# trendy topics.  Each topic had multiple interpretations, some of which
# we suspected would "intersect" in interesting ways (e.g., Trump/Putin, Cloud/Google,
# Cloud/Climate).  Others had various interpretations (e.g., there are many types of
# Football).  See _Wikipedia.ipynb_ for the original download code.
#
# Selected topics (for which the top-10 matches were returned by Wikipedia) were:
#
#  * Pennsylvania
#  * Trump
#  * Apple
#  * Google
#  * Farm
#  * Climate
#  * Cloud
#  * Football
#  * Government
#  * Putin
#
# Please write the function `clean_article(article)` that takes a string as input, tokenizes it using `nltk.word_tokenize` (this one is not for Twitter), converts it to lower case, removed stopwords that are present in the set from the cell above, uses `stemmer` (defined above) to cut the word down to its stem, uses `has_letter` (defined above) to remove words that don't have any letters, and only keeps words with length greater than 1.

# %%
# TODO: Write your clean_article function here

# YOUR CODE HERE
nltk.download('punkt')
def clean_article(article):
    # tokenize
    article = nltk.word_tokenize(article)
    # convert to lower case
    article_new = article
    for i in range(0,len(article)):
        article_new[i] = article[i].lower()
    # remove stopwords
    article_new2 = [w for w in article_new if not w in stopwords]
    article_new2 = [stemmer.stem(word) for word in article_new2]
    for i in range(0,len(article_new2)):
        # remove words without letters
        if has_letter(article_new2[i]) == False:
            article_new2[i] = ''
        # keep words of length > 1
        if len(article_new2)<=1:
            article_new2[i] = ''
    
    article_new2 = list(filter(None, article_new2))
    
    return article_new2
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import os

docs = {}

for filename in os.listdir('text'):
    file = open('text/' + filename)
    docs[filename] = clean_article(file.read())
    #print ('Loaded',filename)

print ("All files loaded")
# Out:
# All files loaded

# %%
print(' '.join(docs['Apple Inc..txt'][:50]))
# Out:
# appl american multin technolog compani headquart cupertino california suburb san jose design develop sell consum electron comput softwar onlin servic hardwar product includ iphon smartphon ipad tablet comput mac person comput ipod portabl media player appl watch smartwatch appl tv digit media player appl consum softwar includ maco io oper

# %% [markdown]
# ## Step 5.2. Generate the Vocabulary
#
# As discussed in class, natural language words follow a **Zipfian distribution**, which means that many, sometimes over half, of the unqiue words in a collection of documents only occur once. Limiting the **vocabulary**, or the list of words that are considered for a data science task, often improves both the efficiency and accuracy of the system. In Part 4, we did this manually. Now, we are going to limit the vocabulary of our search engine automatically such that it only considers the 10,000 most frequent words in the document collection. In the next cell, you should:
#
# 1. Create a single list containing the words of each (cleaned) document in succession.
# 2. Use `nltk.FreqDist` to count occurrences of each word
# 3. Make a list called `wordids` that contains the words in decreasing frequency order. For example, the most frequent word in this document collection is "appl", so `wordids[0] = 'appl'`.
# 3. Make a dictionary called `lexicon` that has words as keys and their indices in `wordids` as values.

# %%
# TODO: Create your vocabulary here. We will test the list named wordids and the dictionary named lexicon

# YOUR CODE HERE
# create singe list
full_list = []
keys, values = zip(*docs.items())
for i in range(0,len(values)):
    full_list = full_list + values[i]
    
# count occurrences of each word
fdist = nltk.FreqDist(full_list)

# make list of words in decreasing frequency order
fdist = fdist.most_common(len(fdist))
wordids = fdist
for i in range(0,len(fdist)):
    wordids[i] = fdist[i][0]

# make a dictionary
ids = list(range(0,len(wordids)))
lexicon = dict(zip(wordids,ids))

# %%
print(wordids[:10])
# Out:
# ['appl', 'trump', 'state', 'footbal', 'cloud', 'googl', 'also', 'use', 'govern', 'first']

# %%
assert(lexicon['appl'] == 0)

# %% [markdown]
# ## Step 5.3. Term Frequencies
#
# Similar to Part 4, we are going to create a document-term matrix, but it is going to be a lot bigger now. Write a function `doc_vector(content, lexicon)` that given a cleaned article (as a list of words) and the lexicon, creates a vector of term frequencies. We will define **term frequency** as the number of times the word occurs in the document divided by the number of times the most frequent word in the document occurs. For example, in the document `['a', 'b', 'b']`, 'a' has a term frequency of 0.5 and 'b' has a term frequency of 1.0.
#
# For greatest portability, please use the length of the vocabulary (`lexicon`) to determine the length of the output vector. Do not hard code the number 10,000.

# %%
# TODO: Write your doc_vector function here

# YOUR CODE HERE
def doc_vector(content, lexicon):
    keys, values = zip(*lexicon.items())
    nt = list(range(0,len(lexicon)))
    # for each word in the lexicon, count how many times it appears in content
    for i in range(0,len(lexicon)):
        word = keys[i]
        nt[i] = content.count(word)
    # calculate the term frequency depending on the max value
    mostFreq = max(nt)
    tf = list(map(lambda x: (x/mostFreq), nt))

    return tf

# %%
vectors = []
doclist = []

for topic in docs:
    doclist.append(topic)
    vectors.append(doc_vector(docs[topic], lexicon))

vectors = np.array(vectors)

# %%
lexicon
# Out:
# {'appl': 0,
#  'trump': 1,
#  'state': 2,
#  'footbal': 3,
#  'cloud': 4,
#  'googl': 5,
#  'also': 6,
#  'use': 7,
#  'govern': 8,
#  'first': 9,
#  'pennsylvania': 10,
#  'new': 11,
#  'putin': 12,
#  'can': 13,
#  'game': 14,
#  'includ': 15,
#  'play': 16,
#  'climat': 17,
#  'one': 18,
#  'farm': 19,
#  'year': 20,
#  'unit': 21,
#  'team': 22,
#  'time': 23,
#  'servic': 24,
#  'may': 25,
#  'leagu': 26,
#  'nation': 27,
#  'compani': 28,
#  'two': 29,
#  'gener': 30,
#  'system': 31,
#  'russia': 32,
#  'develop': 33,
#  'rule': 34,
#  'player': 35,
#  'form': 36,
#  'user': 37,
#  'russian': 38,
#  'comput': 39,
#  'million': 40,
#  'citi': 41,
#  'public': 42,
#  'univers': 43,
#  'chang': 44,
#  'world': 45,
#  'power': 46,
#  'american': 47,
#  'mani': 48,
#  'call': 49,
#  'club': 50,
#  'search': 51,
#  'presid': 52,
#  'number': 53,
#  'associ': 54,
#  'provid': 55,
#  'follow': 56,
#  'area': 57,
#  'will': 58,
#  'countri': 59,
#  'part': 60,
#  'allow': 61,
#  'ball': 62,
#  'local': 63,
#  'name': 64,
#  'elect': 65,
#  'product': 66,
#  'work': 67,
#  'organ': 68,
#  'support': 69,
#  'ii': 70,
#  'book': 71,
#  'featur': 72,
#  'region': 73,
#  'howev': 74,
#  'intern': 75,
#  'line': 76,
#  'result': 77,
#  'major': 78,
#  'store': 79,
#  'model': 80,
#  'york': 81,
#  'refer': 82,
#  'three': 83,
#  'control': 84,
#  'oper': 85,
#  'busi': 86,
#  'found': 87,
#  'sinc': 88,
#  'school': 89,
#  'peopl': 90,
#  'larg': 91,
#  'later': 92,
#  'sever': 93,
#  'cup': 94,
#  'origin': 95,
#  'known': 96,
#  'made': 97,
#  'make': 98,
#  'end': 99,
#  'feder': 100,
#  'wind': 101,
#  'commun': 102,
#  'video': 103,
#  'tv': 104,
#  'report': 105,
#  'high': 106,
#  'member': 107,
#  'type': 108,
#  'minist': 109,
#  'well': 110,
#  'run': 111,
#  'offici': 112,
#  'base': 113,
#  'produc': 114,
#  'manag': 115,
#  'term': 116,
#  'law': 117,
#  'level': 118,
#  'earli': 119,
#  'group': 120,
#  'polit': 121,
#  'creat': 122,
#  'second': 123,
#  'accord': 124,
#  'design': 125,
#  'author': 126,
#  'softwar': 127,
#  'head': 128,
#  'season': 129,
#  'sport': 130,
#  'said': 131,
#  'colleg': 132,
#  'war': 133,
#  'project': 134,
#  'like': 135,
#  'home': 136,
#  'becam': 137,
#  'announc': 138,
#  'histori': 139,
#  'list': 140,
#  'place': 141,
#  'data': 142,
#  'locat': 143,
#  'build': 144,
#  'increas': 145,
#  'day': 146,
#  'publish': 147,
#  'temperatur': 148,
#  'releas': 149,
#  'applic': 150,
#  'popular': 151,
#  'often': 152,
#  'field': 153,
#  'air': 154,
#  'continu': 155,
#  'hous': 156,
#  'differ': 157,
#  'counti': 158,
#  'program': 159,
#  'claim': 160,
#  'becom': 161,
#  'set': 162,
#  'philadelphia': 163,
#  'goal': 164,
#  'u.s.': 165,
#  'record': 166,
#  'council': 167,
#  'octob': 168,
#  'municip': 169,
#  'although': 170,
#  'requir': 171,
#  'parti': 172,
#  'inform': 173,
#  'south': 174,
#  'exampl': 175,
#  'march': 176,
#  'addit': 177,
#  'appear': 178,
#  'even': 179,
#  'case': 180,
#  'point': 181,
#  'divis': 182,
#  'avail': 183,
#  'code': 184,
#  'person': 185,
#  'receiv': 186,
#  'offic': 187,
#  'centuri': 188,
#  'within': 189,
#  'page': 190,
#  'anim': 191,
#  'tax': 192,
#  'relat': 193,
#  'usual': 194,
#  'north': 195,
#  'execut': 196,
#  'energi': 197,
#  'australian': 198,
#  'file': 199,
#  'repres': 200,
#  'link': 201,
#  'effect': 202,
#  'june': 203,
#  'caus': 204,
#  'now': 205,
#  'remain': 206,
#  'open': 207,
#  'forc': 208,
#  'competit': 209,
#  'share': 210,
#  'access': 211,
#  'england': 212,
#  'rugbi': 213,
#  'current': 214,
#  'without': 215,
#  'four': 216,
#  'donald': 217,
#  'network': 218,
#  'decemb': 219,
#  'union': 220,
#  'show': 221,
#  'due': 222,
#  'media': 223,
#  'court': 224,
#  'central': 225,
#  'word': 226,
#  'began': 227,
#  'respons': 228,
#  'market': 229,
#  'see': 230,
#  'constitut': 231,
#  'format': 232,
#  'januari': 233,
#  'novemb': 234,
#  'start': 235,
#  'around': 236,
#  'won': 237,
#  'app': 238,
#  'august': 239,
#  'site': 240,
#  'australia': 241,
#  'water': 242,
#  'kick': 243,
#  'among': 244,
#  'period': 245,
#  'former': 246,
#  'vote': 247,
#  'technolog': 248,
#  'west': 249,
#  'septemb': 250,
#  'introduc': 251,
#  'websit': 252,
#  'center': 253,
#  'establish': 254,
#  'european': 255,
#  'success': 256,
#  'titl': 257,
#  'bowl': 258,
#  'pass': 259,
#  'activ': 260,
#  'process': 261,
#  'english': 262,
#  'along': 263,
#  'much': 264,
#  'prime': 265,
#  'posit': 266,
#  'variou': 267,
#  'account': 268,
#  'common': 269,
#  'take': 270,
#  'campaign': 271,
#  'ocean': 272,
#  'anoth': 273,
#  'april': 274,
#  'engin': 275,
#  'similar': 276,
#  'district': 277,
#  'order': 278,
#  'limit': 279,
#  'held': 280,
#  'match': 281,
#  'still': 282,
#  'plan': 283,
#  'consid': 284,
#  'third': 285,
#  'largest': 286,
#  'offer': 287,
#  'board': 288,
#  'juli': 289,
#  'billion': 290,
#  'move': 291,
#  'top': 292,
#  'popul': 293,
#  'right': 294,
#  'act': 295,
#  'us': 296,
#  'five': 297,
#  'job': 298,
#  'score': 299,
#  'industri': 300,
#  'need': 301,
#  'way': 302,
#  'america': 303,
#  'ad': 304,
#  'display': 305,
#  'content': 306,
#  'back': 307,
#  'polici': 308,
#  'google+': 309,
#  'exist': 310,
#  'month': 311,
#  'purchas': 312,
#  'win': 313,
#  'version': 314,
#  'present': 315,
#  'british': 316,
#  'initi': 317,
#  'per': 318,
#  'confer': 319,
#  'consist': 320,
#  'issu': 321,
#  'total': 322,
#  'german': 323,
#  'averag': 324,
#  'februari': 325,
#  'librari': 326,
#  'global': 327,
#  'sold': 328,
#  'direct': 329,
#  'fa': 330,
#  'devic': 331,
#  'land': 332,
#  'john': 333,
#  'secur': 334,
#  'launch': 335,
#  'complet': 336,
#  'size': 337,
#  'say': 338,
#  'precipit': 339,
#  'import': 340,
#  'small': 341,
#  'meet': 342,
#  'depart': 343,
#  'earth': 344,
#  'administr': 345,
#  'final': 346,
#  'privat': 347,
#  'help': 348,
#  'particip': 349,
#  'atmospher': 350,
#  'extern': 351,
#  'side': 352,
#  'agenc': 353,
#  'women': 354,
#  'prr': 355,
#  'must': 356,
#  'though': 357,
#  'free': 358,
#  'properti': 359,
#  'annual': 360,
#  'legal': 361,
#  'famili': 362,
#  'either': 363,
#  'profession': 364,
#  'view': 365,
#  'lawsuit': 366,
#  'talk': 367,
#  'sign': 368,
#  'onlin': 369,
#  'seri': 370,
#  'ground': 371,
#  'event': 372,
#  'specif': 373,
#  'class': 374,
#  'western': 375,
#  'militari': 376,
#  'sourc': 377,
#  'low': 378,
#  'critic': 379,
#  'describ': 380,
#  'involv': 381,
#  'led': 382,
#  'function': 383,
#  'internet': 384,
#  'reduc': 385,
#  'everi': 386,
#  'signific': 387,
#  'citizen': 388,
#  'e-govern': 389,
#  'isbn': 390,
#  'europ': 391,
#  'lower': 392,
#  'mean': 393,
#  'long': 394,
#  'real': 395,
#  'collect': 396,
#  'took': 397,
#  'coloni': 398,
#  'text': 399,
#  'web': 400,
#  'go': 401,
#  'research': 402,
#  'sale': 403,
#  'bodi': 404,
#  's': 405,
#  'attempt': 406,
#  'return': 407,
#  'leader': 408,
#  'rate': 409,
#  'possibl': 410,
#  'lead': 411,
#  'histor': 412,
#  'summer': 413,
#  'presidenti': 414,
#  'replac': 415,
#  'capit': 416,
#  'championship': 417,
#  'hp': 418,
#  'interest': 419,
#  'financi': 420,
#  'begin': 421,
#  'estat': 422,
#  'corpor': 423,
#  'digit': 424,
#  'price': 425,
#  'cumulu': 426,
#  'hold': 427,
#  'throughout': 428,
#  'great': 429,
#  'near': 430,
#  'varieti': 431,
#  'standard': 432,
#  'least': 433,
#  'modern': 434,
#  'governor': 435,
#  'late': 436,
#  'reach': 437,
#  'independ': 438,
#  'hotel': 439,
#  'territori': 440,
#  'distribut': 441,
#  'occur': 442,
#  'main': 443,
#  'nfl': 444,
#  'desert': 445,
#  'experi': 446,
#  'east': 447,
#  'appoint': 448,
#  'divid': 449,
#  'retail': 450,
#  'serv': 451,
#  'resourc': 452,
#  'across': 453,
#  'rank': 454,
#  'vladimir': 455,
#  'mobil': 456,
#  'rather': 457,
#  'parliament': 458,
#  'recent': 459,
#  'soviet': 460,
#  'just': 461,
#  'custom': 462,
#  'social': 463,
#  'connect': 464,
#  'studi': 465,
#  'press': 466,
#  'disk': 467,
#  'built': 468,
#  'rang': 469,
#  'mountain': 470,
#  'altitud': 471,
#  'winter': 472,
#  'speci': 473,
#  'tower': 474,
#  'given': 475,
#  'contain': 476,
#  'card': 477,
#  'iii': 478,
#  'railroad': 479,
#  '°c': 480,
#  'brook': 481,
#  'enabl': 482,
#  'structur': 483,
#  'higher': 484,
#  'wide': 485,
#  'propos': 486,
#  'live': 487,
#  'outsid': 488,
#  'educ': 489,
#  'languag': 490,
#  'typic': 491,
#  'close': 492,
#  'select': 493,
#  'pay': 494,
#  'particl': 495,
#  'turn': 496,
#  'came': 497,
#  'determin': 498,
#  'role': 499,
#  'drive': 500,
#  'white': 501,
#  'deal': 502,
#  'individu': 503,
#  'institut': 504,
#  'agricultur': 505,
#  'republican': 506,
#  'action': 507,
#  'alleg': 508,
#  'via': 509,
#  'depend': 510,
#  'surfac': 511,
#  'separ': 512,
#  'incom': 513,
#  'washington': 514,
#  'platform': 515,
#  'human': 516,
#  'southern': 517,
#  'bill': 518,
#  'toward': 519,
#  'less': 520,
#  'promot': 521,
#  'pittsburgh': 522,
#  'note': 523,
#  'except': 524,
#  'suggest': 525,
#  'california': 526,
#  'sometim': 527,
#  'street': 528,
#  'william': 529,
#  'rise': 530,
#  'six': 531,
#  'cost': 532,
#  'opposit': 533,
#  'suit': 534,
#  'employe': 535,
#  'premier': 536,
#  'london': 537,
#  'ukrain': 538,
#  'commonwealth': 539,
#  'electron': 540,
#  'commerci': 541,
#  'color': 542,
#  'northern': 543,
#  '°f': 544,
#  'integr': 545,
#  'econom': 546,
#  'practic': 547,
#  'democrat': 548,
#  'china': 549,
#  'singl': 550,
#  'provinc': 551,
#  'fund': 552,
#  'get': 553,
#  'mark': 554,
#  'civil': 555,
#  'ice': 556,
#  'locomot': 557,
#  'post': 558,
#  'carri': 559,
#  'consum': 560,
#  'age': 561,
#  'weather': 562,
#  'foreign': 563,
#  'instal': 564,
#  'other': 565,
#  'classif': 566,
#  'tradit': 567,
#  'remov': 568,
#  'front': 569,
#  'partner': 570,
#  'iphon': 571,
#  'last': 572,
#  'natur': 573,
#  'champion': 574,
#  'instead': 575,
#  'de': 576,
#  'best': 577,
#  'invest': 578,
#  'hall': 579,
#  'resid': 580,
#  'dutch': 581,
#  'm': 582,
#  'directli': 583,
#  'want': 584,
#  'give': 585,
#  'littl': 586,
#  'combin': 587,
#  'mass': 588,
#  'host': 589,
#  'construct': 590,
#  'owner': 591,
#  'organis': 592,
#  'influenc': 593,
#  'read': 594,
#  'primari': 595,
#  'amount': 596,
#  'committe': 597,
#  'compar': 598,
#  'mediterranean': 599,
#  'condit': 600,
#  'athlet': 601,
#  'station': 602,
#  'french': 603,
#  'televis': 604,
#  'machin': 605,
#  'indic': 606,
#  'cover': 607,
#  'revolut': 608,
#  'ten': 609,
#  'river': 610,
#  'comment': 611,
#  'full': 612,
#  'mac': 613,
#  'valu': 614,
#  'speech': 615,
#  'document': 616,
#  'adopt': 617,
#  'canada': 618,
#  'join': 619,
#  'hand': 620,
#  'penn': 621,
#  'republ': 622,
#  'kingdom': 623,
#  'never': 624,
#  'cool': 625,
#  'own': 626,
#  'life': 627,
#  'award': 628,
#  'coach': 629,
#  'special': 630,
#  'especi': 631,
#  'larger': 632,
#  'storag': 633,
#  'despit': 634,
#  'sell': 635,
#  'scan': 636,
#  'old': 637,
#  'updat': 638,
#  'stop': 639,
#  'decis': 640,
#  'commiss': 641,
#  'tag': 642,
#  'attend': 643,
#  'layer': 644,
#  'solar': 645,
#  'beatl': 646,
#  'town': 647,
#  'certain': 648,
#  'foundat': 649,
#  'assembl': 650,
#  'half': 651,
#  'bank': 652,
#  'advertis': 653,
#  'student': 654,
#  'wrote': 655,
#  'question': 656,
#  'money': 657,
#  'tree': 658,
#  'cold': 659,
#  'observ': 660,
#  'infrastructur': 661,
#  'respect': 662,
#  'improv': 663,
#  'brand': 664,
#  'uk': 665,
#  'today': 666,
#  'germani': 667,
#  'itun': 668,
#  'mw': 669,
#  'moscow': 670,
#  'born': 671,
#  'next': 672,
#  'societi': 673,
#  'problem': 674,
#  'far': 675,
#  'capac': 676,
#  'settl': 677,
#  'park': 678,
#  'georg': 679,
#  'ask': 680,
#  'warm': 681,
#  'poll': 682,
#  'farmer': 683,
#  'messag': 684,
#  'longer': 685,
#  'futur': 686,
#  'look': 687,
#  'vari': 688,
#  'concern': 689,
#  'commonli': 690,
#  'almost': 691,
#  'expans': 692,
#  'perform': 693,
#  'music': 694,
#  'virtual': 695,
#  'su': 696,
#  'train': 697,
#  'stock': 698,
#  'chief': 699,
#  'remot': 700,
#  'stadium': 701,
#  'casino': 702,
#  'put': 703,
#  'inc.': 704,
#  'rel': 705,
#  'estim': 706,
#  'gain': 707,
#  "n't": 708,
#  'approxim': 709,
#  'legisl': 710,
#  'mostli': 711,
#  'ireland': 712,
#  'georgia': 713,
#  'previou': 714,
#  'paid': 715,
#  'oppos': 716,
#  'visit': 717,
#  'articl': 718,
#  'comet': 719,
#  'cours': 720,
#  'capabl': 721,
#  'normal': 722,
#  'tie': 723,
#  'believ': 724,
#  'idea': 725,
#  'zone': 726,
#  'manufactur': 727,
#  'expand': 728,
#  'extend': 729,
#  'variat': 730,
#  'film': 731,
#  'charg': 732,
#  'fall': 733,
#  'youtub': 734,
#  'sun': 735,
#  'droplet': 736,
#  'interfac': 737,
#  'thu': 738,
#  'edit': 739,
#  'strong': 740,
#  'revenu': 741,
#  'grow': 742,
#  'went': 743,
#  'winner': 744,
#  'seven': 745,
#  'growth': 746,
#  'approv': 747,
#  'ga': 748,
#  'come': 749,
#  'seen': 750,
#  'oort': 751,
#  'mayor': 752,
#  'golf': 753,
#  'affect': 754,
#  'hardwar': 755,
#  'space': 756,
#  'middl': 757,
#  'saw': 758,
#  'stream': 759,
#  'grant': 760,
#  'percent': 761,
#  'reform': 762,
#  'physic': 763,
#  'genu': 764,
#  'drop': 765,
#  'download': 766,
#  'movement': 767,
#  'plu': 768,
#  'valley': 769,
#  'track': 770,
#  'maintain': 771,
#  'agreement': 772,
#  'cultur': 773,
#  'past': 774,
#  'food': 775,
#  'rais': 776,
#  'tend': 777,
#  'turbin': 778,
#  'request': 779,
#  'identifi': 780,
#  'object': 781,
#  'statu': 782,
#  'advanc': 783,
#  'coast': 784,
#  'effort': 785,
#  'decad': 786,
#  'acquir': 787,
#  'highest': 788,
#  'defens': 789,
#  'hangout': 790,
#  'defin': 791,
#  'upon': 792,
#  'map': 793,
#  'macintosh': 794,
#  'imag': 795,
#  'met': 796,
#  'notabl': 797,
#  'flag': 798,
#  'arm': 799,
#  'deliv': 800,
#  'agre': 801,
#  'domin': 802,
#  'photo': 803,
#  'declar': 804,
#  'hot': 805,
#  'harvard': 806,
#  'judg': 807,
#  'ukrainian': 808,
#  'server': 809,
#  'nativ': 810,
#  'environ': 811,
#  'lack': 812,
#  'eventu': 813,
#  'particular': 814,
#  'nearli': 815,
#  'light': 816,
#  'violat': 817,
#  'trade': 818,
#  'cook': 819,
#  'protest': 820,
#  'sea': 821,
#  'delawar': 822,
#  'latitud': 823,
#  'father': 824,
#  'face': 825,
#  'method': 826,
#  'implement': 827,
#  'togeth': 828,
#  'church': 829,
#  'exil': 830,
#  'enter': 831,
#  'entir': 832,
#  'black': 833,
#  'death': 834,
#  'week': 835,
#  'senior': 836,
#  'tackl': 837,
#  'aim': 838,
#  'classifi': 839,
#  'democraci': 840,
#  'challeng': 841,
#  'copyright': 842,
#  'vertic': 843,
#  'evid': 844,
#  'client': 845,
#  'favor': 846,
#  'convers': 847,
#  'tool': 848,
#  'subsequ': 849,
#  'licens': 850,
#  'tri': 851,
#  'exercis': 852,
#  'good': 853,
#  'convent': 854,
#  'left': 855,
#  'io': 856,
#  'health': 857,
#  'border': 858,
#  'eastern': 859,
#  'afl': 860,
#  'potenti': 861,
#  'orwel': 862,
#  'third-parti': 863,
#  'extens': 864,
#  'alway': 865,
#  'expect': 866,
#  'port': 867,
#  'abl': 868,
#  'formal': 869,
#  'subject': 870,
#  'protect': 871,
#  'race': 872,
#  'watch': 873,
#  'ipad': 874,
#  'india': 875,
#  'settlement': 876,
#  'mile': 877,
#  'jersey': 878,
#  'convect': 879,
#  'stratu': 880,
#  'offens': 881,
#  'queen': 882,
#  'big': 883,
#  'township': 884,
#  'reason': 885,
#  'measur': 886,
#  'electr': 887,
#  'fruit': 888,
#  'lost': 889,
#  'fame': 890,
#  'behind': 891,
#  'touch': 892,
#  'plant': 893,
#  'keep': 894,
#  'cabinet': 895,
#  'extrem': 896,
#  'ft': 897,
#  'contact': 898,
#  'whether': 899,
#  'numer': 900,
#  'signal': 901,
#  'compet': 902,
#  'actual': 903,
#  'disput': 904,
#  'steve': 905,
#  'quarter': 906,
#  'eight': 907,
#  'letter': 908,
#  'regard': 909,
#  'short': 910,
#  'away': 911,
#  'hour': 912,
#  'appli': 913,
#  'song': 914,
#  'florida': 915,
#  'napoleon': 916,
#  'might': 917,
#  'prevent': 918,
#  'squar': 919,
#  'worth': 920,
#  'reflect': 921,
#  'logo': 922,
#  'shape': 923,
#  'profit': 924,
#  'brought': 925,
#  'basi': 926,
#  'magazin': 927,
#  'franc': 928,
#  'feet': 929,
#  'island': 930,
#  'immigr': 931,
#  'nuclear': 932,
#  'interact': 933,
#  'leav': 934,
#  'write': 935,
#  'screen': 936,
#  'key': 937,
#  'enough': 938,
#  'candid': 939,
#  'minor': 940,
#  'basic': 941,
#  'equip': 942,
#  'address': 943,
#  'hard': 944,
#  'fact': 945,
#  'investig': 946,
#  'pressur': 947,
#  'children': 948,
#  'justic': 949,
#  'soccer': 950,
#  'atlant': 951,
#  'eri': 952,
#  'radiat': 953,
#  'condens': 954,
#  'decid': 955,
#  'express': 956,
#  'chat': 957,
#  'voic': 958,
#  'window': 959,
#  'os': 960,
#  'hybrid': 961,
#  'technic': 962,
#  'latin': 963,
#  'written': 964,
#  'affair': 965,
#  'altern': 966,
#  'suppli': 967,
#  'employ': 968,
#  'clone': 969,
#  'particularli': 970,
#  'facil': 971,
#  'son': 972,
#  'greater': 973,
#  'corp': 974,
#  'loss': 975,
#  'branch': 976,
#  'youth': 977,
#  'injuri': 978,
#  'men': 979,
#  'defeat': 980,
#  'transfer': 981,
#  'cultivar': 982,
#  'previous': 983,
#  'phone': 984,
#  'attribut': 985,
#  'economi': 986,
#  'unlik': 987,
#  'smaller': 988,
#  'accept': 989,
#  'earlier': 990,
#  'director': 991,
#  'box': 992,
#  'illeg': 993,
#  'red': 994,
#  'insur': 995,
#  'fourth': 996,
#  'indian': 997,
#  'king': 998,
#  'worker': 999,
#  ...}

# %%
# This should be document 0
for id in range(0, len(lexicon)):
    if vectors[0, id] > 0:
        print(wordids[id] + ' x ' + str(vectors[0, id]))
# Out:
# state x 0.0522388059701
# googl x 1.0
# also x 0.0746268656716
# use x 0.134328358209
# first x 0.0298507462687
# new x 0.044776119403
# can x 0.10447761194
# includ x 0.0597014925373
# one x 0.0597014925373
# year x 0.00746268656716
# time x 0.0298507462687
# servic x 0.119402985075
# may x 0.0522388059701
# compani x 0.00746268656716
# two x 0.0223880597015
# system x 0.0298507462687
# develop x 0.0223880597015
# player x 0.0149253731343
# user x 0.283582089552
# comput x 0.0149253731343
# univers x 0.00746268656716
# mani x 0.0298507462687
# call x 0.0671641791045
# search x 0.00746268656716
# number x 0.00746268656716
# provid x 0.0597014925373
# area x 0.00746268656716
# will x 0.0671641791045
# countri x 0.00746268656716
# part x 0.0149253731343
# allow x 0.0820895522388
# name x 0.0223880597015
# product x 0.0149253731343
# work x 0.0820895522388
# support x 0.141791044776
# featur x 0.0522388059701
# howev x 0.0373134328358
# intern x 0.00746268656716
# result x 0.00746268656716
# major x 0.00746268656716
# store x 0.00746268656716
# york x 0.00746268656716
# refer x 0.00746268656716
# oper x 0.0149253731343
# found x 0.0223880597015
# sinc x 0.00746268656716
# peopl x 0.00746268656716
# origin x 0.00746268656716
# known x 0.0149253731343
# made x 0.0223880597015
# make x 0.0223880597015
# end x 0.0298507462687
# feder x 0.0223880597015
# commun x 0.0746268656716
# video x 0.0671641791045
# report x 0.0149253731343
# type x 0.00746268656716
# well x 0.0149253731343
# offici x 0.044776119403
# base x 0.00746268656716
# manag x 0.00746268656716
# group x 0.0149253731343
# creat x 0.00746268656716
# accord x 0.00746268656716
# design x 0.0149253731343
# softwar x 0.0149253731343
# like x 0.0298507462687
# becam x 0.00746268656716
# announc x 0.089552238806
# histori x 0.0149253731343
# list x 0.00746268656716
# place x 0.0149253731343
# day x 0.00746268656716
# releas x 0.0820895522388
# applic x 0.0522388059701
# continu x 0.0298507462687
# program x 0.0149253731343
# set x 0.00746268656716
# goal x 0.00746268656716
# record x 0.0149253731343
# octob x 0.0149253731343
# although x 0.0149253731343
# requir x 0.0149253731343
# parti x 0.0223880597015
# inform x 0.00746268656716
# exampl x 0.00746268656716
# march x 0.0149253731343
# appear x 0.00746268656716
# even x 0.0298507462687
# avail x 0.0746268656716
# code x 0.00746268656716
# person x 0.0149253731343
# receiv x 0.0671641791045
# within x 0.0223880597015
# page x 0.0149253731343
# link x 0.0223880597015
# june x 0.0149253731343
# remain x 0.0149253731343
# open x 0.0223880597015
# current x 0.00746268656716
# without x 0.0149253731343
# network x 0.0223880597015
# decemb x 0.0223880597015
# show x 0.0149253731343
# central x 0.00746268656716
# respons x 0.00746268656716
# format x 0.0223880597015
# januari x 0.00746268656716
# novemb x 0.0223880597015
# around x 0.00746268656716
# app x 0.0970149253731
# august x 0.0298507462687
# site x 0.0149253731343
# period x 0.00746268656716
# septemb x 0.0149253731343
# introduc x 0.00746268656716
# activ x 0.00746268656716
# process x 0.00746268656716
# account x 0.0746268656716
# anoth x 0.00746268656716
# april x 0.0223880597015
# engin x 0.00746268656716
# similar x 0.00746268656716
# order x 0.00746268656716
# limit x 0.00746268656716
# held x 0.00746268656716
# match x 0.00746268656716
# still x 0.0373134328358
# plan x 0.0223880597015
# offer x 0.0223880597015
# move x 0.00746268656716
# us x 0.0149253731343
# need x 0.00746268656716
# ad x 0.0298507462687
# content x 0.00746268656716
# back x 0.00746268656716
# google+ x 0.0671641791045
# exist x 0.0149253731343
# month x 0.00746268656716
# version x 0.0298507462687
# present x 0.00746268656716
# initi x 0.00746268656716
# per x 0.00746268656716
# confer x 0.00746268656716
# februari x 0.0746268656716
# librari x 0.0149253731343
# devic x 0.0298507462687
# secur x 0.00746268656716
# launch x 0.0149253731343
# extern x 0.00746268656716
# must x 0.0149253731343
# though x 0.0149253731343
# talk x 0.559701492537
# sign x 0.0298507462687
# onlin x 0.0149253731343
# event x 0.00746268656716
# specif x 0.0149253731343
# function x 0.044776119403
# internet x 0.00746268656716
# reduc x 0.00746268656716
# mean x 0.0223880597015
# long x 0.0298507462687
# real x 0.00746268656716
# text x 0.111940298507
# web x 0.0298507462687
# go x 0.00746268656716
# s x 0.00746268656716
# attempt x 0.00746268656716
# return x 0.00746268656716
# possibl x 0.0298507462687
# replac x 0.0223880597015
# corpor x 0.00746268656716
# varieti x 0.00746268656716
# standard x 0.0223880597015
# least x 0.00746268656716
# experi x 0.00746268656716
# mobil x 0.0522388059701
# recent x 0.0149253731343
# connect x 0.044776119403
# given x 0.00746268656716
# contain x 0.00746268656716
# enabl x 0.0522388059701
# outsid x 0.0149253731343
# turn x 0.0149253731343
# came x 0.00746268656716
# individu x 0.00746268656716
# via x 0.0149253731343
# depend x 0.00746268656716
# platform x 0.0149253731343
# note x 0.00746268656716
# except x 0.00746268656716
# suggest x 0.00746268656716
# california x 0.00746268656716
# integr x 0.0746268656716
# post x 0.0149253731343
# instal x 0.0149253731343
# other x 0.00746268656716
# last x 0.00746268656716
# instead x 0.00746268656716
# directli x 0.00746268656716
# want x 0.00746268656716
# give x 0.00746268656716
# owner x 0.0373134328358
# full x 0.0223880597015
# mac x 0.0223880597015
# special x 0.0149253731343
# updat x 0.0223880597015
# stop x 0.0149253731343
# respect x 0.00746268656716
# next x 0.00746268656716
# messag x 0.149253731343
# longer x 0.00746268656716
# futur x 0.0149253731343
# look x 0.00746268656716
# put x 0.0223880597015
# n't x 0.0223880597015
# approxim x 0.00746268656716
# capabl x 0.0149253731343
# normal x 0.00746268656716
# interfac x 0.00746268656716
# thu x 0.00746268656716
# edit x 0.00746268656716
# drop x 0.0149253731343
# download x 0.0298507462687
# request x 0.00746268656716
# hangout x 0.089552238806
# server x 0.0671641791045
# nativ x 0.0149253731343
# environ x 0.00746268656716
# lack x 0.00746268656716
# eventu x 0.00746268656716
# face x 0.00746268656716
# method x 0.00746268656716
# implement x 0.00746268656716
# aim x 0.0149253731343
# client x 0.15671641791
# favor x 0.00746268656716
# convers x 0.0223880597015
# tool x 0.0149253731343
# subsequ x 0.00746268656716
# licens x 0.00746268656716
# tri x 0.0149253731343
# third-parti x 0.0373134328358
# extens x 0.0223880597015
# alway x 0.00746268656716
# expect x 0.0149253731343
# port x 0.0223880597015
# abl x 0.0149253731343
# formal x 0.00746268656716
# contact x 0.044776119403
# whether x 0.00746268656716
# numer x 0.0149253731343
# signal x 0.0149253731343
# might x 0.00746268656716
# interact x 0.00746268656716
# leav x 0.00746268656716
# write x 0.00746268656716
# screen x 0.00746268656716
# chat x 0.268656716418
# voic x 0.0970149253731
# window x 0.089552238806
# os x 0.0149253731343
# hybrid x 0.0149253731343
# technic x 0.00746268656716
# previous x 0.0149253731343
# phone x 0.0522388059701
# minut x 0.00746268656716
# date x 0.00746268656716
# sent x 0.0298507462687
# detail x 0.0149253731343
# thousand x 0.00746268656716
# abil x 0.00746268656716
# android x 0.0298507462687
# circl x 0.00746268656716
# microsoft x 0.0149253731343
# confirm x 0.00746268656716
# compat x 0.0298507462687
# transport x 0.00746268656716
# soon x 0.00746268656716
# error x 0.00746268656716
# let x 0.00746268656716
# save x 0.00746268656716
# insid x 0.00746268656716
# respond x 0.00746268656716
# gmail x 0.149253731343
# x x 0.00746268656716
# instant x 0.044776119403
# discontinu x 0.0223880597015
# browser x 0.0298507462687
# shown x 0.00746268656716
# friend x 0.00746268656716
# reveal x 0.0149253731343
# suspend x 0.00746268656716
# yet x 0.0149253731343
# automat x 0.00746268656716
# upgrad x 0.0298507462687
# email x 0.00746268656716
# built-in x 0.00746268656716
# send x 0.0298507462687
# blackberri x 0.0223880597015
# adium x 0.0149253731343
# im x 0.0149253731343
# iter x 0.00746268656716
# imp x 0.0223880597015
# unus x 0.00746268656716
# ital x 0.0149253731343
# dash x 0.00746268656716
# rumor x 0.00746268656716
# eager x 0.00746268656716
# usernam x 0.0149253731343
# libjingl x 0.0223880597015
# bsd x 0.00746268656716
# skype x 0.0223880597015
# aol x 0.00746268656716
# anonym x 0.00746268656716
# slate x 0.00746268656716
# non-googl x 0.00746268656716
# isp x 0.00746268656716
# psi x 0.00746268656716
# imap x 0.00746268656716
# igoogl x 0.0149253731343
# xp x 0.00746268656716
# vista x 0.00746268656716
# intel-bas x 0.00746268656716
# binari x 0.00746268656716
# otr x 0.0149253731343
# off-the-record x 0.0149253731343
# soni x 0.00746268656716
# underscor x 0.00746268656716
# c++ x 0.00746268656716
# ietf x 0.00746268656716
# irc x 0.00746268656716
# forev x 0.00746268656716
# clarif x 0.00746268656716
# purportedli x 0.00746268656716
# gchat x 0.00746268656716
# gtalk x 0.00746268656716
# gmessag x 0.00746268656716
# gajim x 0.00746268656716
# earthlink x 0.00746268656716
# gizmo5 x 0.00746268656716
# tiscali x 0.00746268656716
# neteas x 0.00746268656716
# chikka x 0.00746268656716
# mediar x 0.00746268656716
# workaround x 0.00746268656716
# takeout x 0.00746268656716
# 'scrap x 0.00746268656716
# outbound x 0.00746268656716
# voicemail x 0.00746268656716
# debian x 0.00746268656716
# ubuntu x 0.00746268656716
# fedora x 0.00746268656716
# opensus x 0.00746268656716
# seamlessli x 0.00746268656716
# imlog x 0.00746268656716
# unencrypt x 0.00746268656716
# gmail-account x 0.00746268656716
# xmpp-base x 0.00746268656716
# talk-compat x 0.00746268656716
# mylo x 0.00746268656716
# unsign x 0.00746268656716
# midlet x 0.00746268656716
# xmpp/imp x 0.00746268656716
# symbian-bas x 0.00746268656716
# nimbuzz x 0.00746268656716
# asterisk x 0.00746268656716
# *thi x 0.00746268656716
# talk* x 0.00746268656716
# strike-through x 0.00746268656716
# google-brand x 0.00746268656716
# subdomain x 0.00746268656716
# talk.google.com x 0.00746268656716
# logged-in x 0.00746268656716
# disconnect x 0.00746268656716
# utc x 0.00746268656716
# gmail.com x 0.00746268656716
# 5222-connect x 0.00746268656716
# re-en x 0.00746268656716
# server-to-serv x 0.00746268656716
# dialback x 0.00746268656716
# server–brows x 0.00746268656716
# sip x 0.00746268656716
# userbas x 0.00746268656716
# flash-bas x 0.00746268656716
# chatback x 0.00746268656716
# clue x 0.00746268656716
# revamp x 0.00746268656716
# nikhyl x 0.00746268656716
# life/retir x 0.00746268656716
# feb x 0.00746268656716
# mayur x 0.00746268656716
# kamat x 0.00746268656716
# relied-on x 0.00746268656716
# chrome-intern x 0.00746268656716
# windows-specif x 0.00746268656716
# cessat x 0.00746268656716
# 23rd x 0.00746268656716
# talkabout x 0.00746268656716

# %% [markdown]
# ## Step 5.4. Inverse Document Frequencies
#
# We would like to give **rare words** a higher weight than ones found in all documents.  To measure a word’s rareness, we will develop a metric called **inverse document frequency (idf)**.  In its simplest form, a word’s idf is a ratio between the total number of documents, and how many documents include a word.  (Note that the idf is independent of a given document -- it is a measure of the word’s popularity across the full set of documents, sometimes called a **corpus**.)  Typically, we don’t directly use the ratio, however -- instead we use its base-10 logarithm.  Thus, we define:
#
# $$idf(w) = \log(\frac{\text{total number of docs}}{\text{number of docs containing }w})$$
#
# Now compute a single vector `idf` representing, for each word, its idf within the corpus.

# %%
idf = []
# TODO: Populate the idf list with idf values across the vocabulary

# YOUR CODE HERE
import math
idf = list(range(0,len(lexicon)))
nDocs = len(docs)
for i in range(0,len(lexicon)):
    nDocsW = sum(vectors[:,i]!=0)
    idf[i] = math.log10(nDocs/nDocsW)

# %%
# len(idf) # 18,075
# MAX_WORDS
len(lexicon)
# Out:
# 18075

# %%
for i in range(0, len(wordids)):
    print(wordids[i], idf[i])
# Out:
# appl 0.6901960800285137
# trump 0.91204482964487
# state 0.06694678963061322
# footbal 0.760777154314221
# cloud 0.6901960800285137
# googl 0.7359535705891889
# also 0.018098222092796223
# use 0.09913147300201444
# govern 0.3010299956639812
# first 0.13389357926122641
# pennsylvania 0.6690067809585756
# new 0.11041248341170351
# putin 0.91204482964487
# can 0.13996772697341955
# game 0.5762527277216769
# includ 0.051706823073876314
# play 0.3284682440109208
# climat 0.5762527277216769
# one 0.05672762444892715
# farm 0.6690067809585756
# year 0.13996772697341955
# unit 0.11041248341170351
# team 0.49986438185822213
# time 0.13996772697341955
# servic 0.3191282177567774
# may 0.07741222330877814
# leagu 0.6488033948702886
# nation 0.2277980821295576
# compani 0.3284682440109208
# two 0.1850461017086077
# gener 0.12790321557203896
# system 0.21307482530885122
# russia 0.7359535705891889
# develop 0.17831271904963927
# rule 0.40016146866599567
# player 0.6690067809585756
# form 0.1716821401506262
# user 0.6901960800285137
# russian 0.7359535705891889
# comput 0.6110148339808888
# million 0.3784422189727593
# citi 0.292256071356476
# public 0.250863386198251
# univers 0.24303804868629442
# chang 0.2588323158695264
# world 0.250863386198251
# power 0.33801356191715115
# american 0.23535122002000347
# mani 0.12199435596151867
# call 0.17831271904963927
# club 0.6488033948702886
# search 0.7124724747396659
# presid 0.33801356191715115
# number 0.15237698495523957
# associ 0.250863386198251
# provid 0.250863386198251
# follow 0.12199435596151867
# area 0.21307482530885122
# will 0.22037406405035068
# countri 0.2588323158695264
# part 0.12199435596151867
# allow 0.2277980821295576
# ball 0.9498333905342697
# local 0.2752227320576957
# name 0.19188552623891314
# elect 0.45974715865023974
# product 0.3477733992063074
# work 0.19188552623891314
# organ 0.2588323158695264
# support 0.19883438619424096
# ii 0.5440680443502757
# book 0.4860760973725889
# featur 0.2752227320576957
# region 0.3010299956639812
# howev 0.1716821401506262
# intern 0.24303804868629442
# line 0.36797678529459443
# result 0.24303804868629442
# major 0.19883438619424096
# store 0.7124724747396659
# model 0.5141048209728324
# york 0.4114424790756847
# refer 0.013502470403647132
# three 0.15871716298625854
# control 0.3191282177567774
# oper 0.3284682440109208
# busi 0.4230243516254999
query = doc_vector(clean_article('Google Apple Google'), lexicon)

for id in range(0, len(lexicon)):
    if query[id] > 0:
        print("%10s"%wordids[id] + ' x ' + str(query[id]))
# Out:
#       appl x 0.5
#      googl x 1.0

# %% [markdown]
# To compute the similarity between two documents, we use the cosine of the angle between their vectors, given by:
#
# $$sim(d_1,d_2) = \frac{d_1 \cdot d_2}{||d_1||\;||d_2||}$$
#
# where $||d_i||$ is the Frobenius ($L_2$) norm of the document vector. Write a function `search(vectors, doclist, idf, query, num_results)` that, when given a 2D array of document vectors, a list of document names, idf scores for each word, a query vector, and the desired number of results:
#
# 1. Creates a Pandas DataFrame with schema (docid, docname, score) for the results of matching the query against each document.
# 2. Scales the words in the document and query vectors by their idfs.
# 3. Computes the cosine similarity score for the query against each document. Hint: Uses Numpy multiplication (`*` between arrays), dot product (`@` or `np.dotproduct()`) and other operations (`+`, `np.linalg.norm()` for vector norms, etc.)
# 4. Adds each document ID and score to the DataFrame.
# 5. Sorts the DataFrame by descending score.
# 6. Returns the first `num_results` results.

# %%
# TODO: Implement the search function here

# YOUR CODE HERE
def search(vectors, doclist, idf, query, num_results):
    import pandas as pd
    import numpy as np
    # create a Pandas DF
    d = {'docid': [], 'docname': [], 'score': []}
    results = pd.DataFrame(data=d)
    
    # scale the words by their idfs
    scaled_vect = vectors * idf
    scaled_query = np.array(query) * idf
    
    # compute cosine similarity
    score = list(range(0,len(doclist)))
    for i in range(0,len(doclist)):
        vect = scaled_vect[i] # vector for this document
        score[i] = np.dot(vect,scaled_query) / (np.linalg.norm(vect) * np.linalg.norm(scaled_query))
        
    # add doc ID and score to DF
    ids = list(range(1,len(doclist)+1))
    d = {'docid': ids, 'docname': doclist, 'score': score}
    results = pd.DataFrame(data=d)
    
    # sort DF by descending score
    results = results.sort_values(by=['score'],ascending=False).reset_index(drop=True)
    
    # find first num_results results
    final = results[0:num_results]
    
    return final

# %%
result = search(vectors, doclist, idf, doc_vector(clean_article('apple computer steve jobs'), lexicon), 10)
display(result)
# Out:
#    docid              docname     score
# 0     17          Apple I.txt  0.535743
# 1      6       Apple Inc..txt  0.473741
# 2     75        Apple III.txt  0.401054
# 3      3  Apple II series.txt  0.365331
# 4     32      Apple Store.txt  0.326945
# 5     79            Apple.txt  0.301920
# 6     38         Apple TV.txt  0.285315
# 7     52    Cooking apple.txt  0.278273
# 8     86      Apple Corps.txt  0.260448
# 9     36  Cloud computing.txt  0.158311

# %%
result = search(vectors, doclist, idf, doc_vector(clean_article('Trump Putin'), lexicon), 10)
display(result)
# Out:
#    docid                             docname     score
# 0     21                    Donald Trump.txt  0.661581
# 1     65   Legal affairs of Donald Trump.txt  0.636282
# 2     39          The Trump Organization.txt  0.628068
# 3     28                Trump University.txt  0.593630
# 4     20  Public image of Vladimir Putin.txt  0.591325
# 5     66          Family of Donald Trump.txt  0.587025
# 6     80                  Vladimir Putin.txt  0.576733
# 7     97                    Trump family.txt  0.523480
# 8     42                      Eric Trump.txt  0.486722
# 9     35     Russia under Vladimir Putin.txt  0.464057
